# %%
import numpy as np
from PIL import Image
import os
import random

# %%
def get_host():

  newsize = (256, 256)

  image = Image.open("./host.jpg")
  image = image.resize(newsize)
  data = np.asarray(image)
  pixels_image = image.load() 
  display(image)  

  img_width, img_height, = image.size #Size of the image I want

  return image, pixels_image

# %%
image, pixels_image = get_host()
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8B5E64BF50>

# %%
def secret():

  img_sec = Image.open("./sec.jpg").convert('L')
  img_sec = img_sec.resize((256, 256))
  pixels_img_sec = img_sec.load()

  return img_sec, pixels_img_sec

# %%
img_sec, pixels_img_sec = secret()

# %%
def listToString(s): 
    
    # initialize an empty string
    str1 = "" 
    
    # traverse in the string  
    for ele in s: 
        str1 += ele  
    
    # return string  
    return str1

# %%
def embedding():

  for i in range(256):
      for j in range(256):
          binary_r,binary_g,binary_b=format(pixels_image[i,j][0],'08b'),format(pixels_image[i,j][1],'08b'),format(pixels_image[i,j][2],'08b')
          
          binary_r = list(binary_r)
          binary_g = list(binary_g)
          binary_b = list(binary_b)
          
          binary_r[7]=format(pixels_img_sec[i,j],'08b')[0]
          binary_g[7]=format(pixels_img_sec[i,j],'08b')[1]
          binary_b[7]=format(pixels_img_sec[i,j],'08b')[2]

          binary_r[6]=format(pixels_img_sec[i,j],'08b')[3]
          binary_g[6]=format(pixels_img_sec[i,j],'08b')[4]
          binary_b[6]=format(pixels_img_sec[i,j],'08b')[5]
          
          str_pix_r=listToString(binary_r)
          str_pix_g=listToString(binary_g)
          str_pix_b=listToString(binary_b)
          pixels_image[i,j]=(int(str_pix_r,2),int(str_pix_g,2),int(str_pix_b,2))

  display(image)
  image1 = image.save("gomulu.jpg")
embedding()
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8B5E64BF50>

# %%
x = random.randint(0,255)
y = x
x = bytearray(x)
print(x)
# Out:
# bytearray(b'')

# %%
try:
    # take path of image as a input
    
    path = "./gomulu.jpg"
      
    # taking encryption key as input
    key = "./key.txt"
    file_a = open(key, 'wb')
    key1 = file_a.write(x)
    print(key1)

    file_a.close()
      
    # print path of image file and encryption key that
    # we are using
    print('The path of file : ', path)
 
      
    # open file for reading purpose
    fin = open(path, 'rb')

      
    # storing image data in variable "image"
    image1 = fin.read()

    fin.close()
    
    # converting image into byte array to 
    # perform encryption easily on numeric data
    image1 = bytearray(image1)


    print("fdgdf")
    # performing XOR operation on each value of bytearray
    for index, values in enumerate(image1):
     
        image1[index] = values ^ key1
    
    print("weery")
  
    # opening file for writting purpose
    fin = open(path, 'wb')
      
    # writing encrypted data in image
    fin.write(image1)

    fin.close()
    print('Encryption Done...')
    os.remove("key.txt")
      
except Exception:
    print('Error caught : ', Exception.__name__)# try block to handle exception
# Out:
# 104
# The path of file :  ./gomulu.jpg
# fdgdf
# weery
# Encryption Done...

# %%
# try block to handle the exception



while (y == key1):
  try:

      path = "./gomulu.jpg"
      
      # print path of image file and decryption key that we are using
      print('The path of file : ', path)
      print('Note : Encryption key and Decryption key must be same.')
      print('Key for Decryption : ', key1)
      
      # open file for reading purpose
      fin = open(path, 'rb')
      
      # storing image data in variable "image"
      image1 = fin.read()
      fin.close()

      # converting image into byte array to perform decryption easily on numeric data
      image1 = bytearray(image1)
  
      # performing XOR operation on each value of bytearray
      for index, values in enumerate(image1):
          image1[index] = values ^ key1
  
      # opening file for writting purpose
      fin = open(path, 'wb')
      
      # writing decryption data in image
      fin.write(image1)
    
      fin.close()


      
      print('Decryption Done...')
      dec_gray = Image.new('L', (256, 256))
      dec_pixels = dec_gray.load()
      for i in range(256):
        for j in range(256):
          binary_r,binary_g,binary_b=format(pixels_image[i,j][0],'08b'),format(pixels_image[i,j][1],'08b'),format(pixels_image[i,j][2],'08b')

        
          binary_r = list(binary_r)
          binary_g = list(binary_g)
          binary_b = list(binary_b)
      

          dec_pix_0=binary_r[7]
          dec_pix_1=binary_g[7]
          dec_pix_2=binary_b[7]

          dec_pix_3=binary_r[6]
          dec_pix_4=binary_g[6]
          dec_pix_5=binary_b[6]
   

          dec_value=[dec_pix_0,dec_pix_1,dec_pix_2,dec_pix_3,dec_pix_4,dec_pix_5,str("0"),str("0")]
          str_dec_value=listToString(dec_value)
          dec_pixels[i,j]=(int(str_dec_value,2))



  except Exception:
    print('Error caught : ', Exception.__name__)
  break
# Out:
# The path of file :  ./gomulu.jpg
# Note : Encryption key and Decryption key must be same.
# Key for Decryption :  104
# Decryption Done...

# %%
display(dec_gray)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7F8B58B4DC10>
